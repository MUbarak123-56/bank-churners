# %% [markdown]
# ## Putting it all together

# %%
import seaborn as sns; sns.set_style("dark")
import pandas as pd
# %matplotlib inline 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, LabelEncoder, StandardScaler, Normalizer, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import janitor
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso, ElasticNetCV
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, accuracy_score, f1_score, recall_score, precision_score
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve, confusion_matrix
from sklearn.feature_selection import RFECV
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from skopt import BayesSearchCV
from xgboost import XGBClassifier
import janitor

# %%
data = pd.read_csv("data/bankchurnersuse.csv").clean_names()

# %%
data
# Out:
#        clientnum     attrition_flag  customer_age gender  dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       education_level marital_status income_category card_category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        months_on_book  ...  months_inactive_12_mon  contacts_count_12_mon  \
# 0                  39  ...                       1                      3
# 1                  44  ...                       1                      2
# 2                  36  ...                       1                      0
# 3                  34  ...                       4                      1
# 4                  21  ...                       1                      0
# ...               ...  ...                     ...                    ...
# 10122              40  ...                       2                      3
# 10123              25  ...                       2                      3
# 10124              36  ...                       3                      4
# 10125              36  ...                       3                      3
# 10126              25  ...                       2                      4
#
#        credit_limit  total_revolving_bal  avg_open_to_buy  \
# 0           12691.0                  777          11914.0
# 1            8256.0                  864           7392.0
# 2            3418.0                    0           3418.0
# 3            3313.0                 2517            796.0
# 4            4716.0                    0           4716.0
# ...             ...                  ...              ...
# 10122        4003.0                 1851           2152.0
# 10123        4277.0                 2186           2091.0
# 10124        5409.0                    0           5409.0
# 10125        5281.0                    0           5281.0
# 10126       10388.0                 1961           8427.0
#
#        total_amt_chng_q4_q1  total_trans_amt  total_trans_ct  \
# 0                     1.335             1144              42
# 1                     1.541             1291              33
# 2                     2.594             1887              20
# 3                     1.405             1171              20
# 4                     2.175              816              28
# ...                     ...              ...             ...
# 10122                 0.703            15476             117
# 10123                 0.804             8764              69
# 10124                 0.819            10291              60
# 10125                 0.535             8395              62
# 10126                 0.703            10294              61
#
#        total_ct_chng_q4_q1  avg_utilization_ratio
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
# [10127 rows x 21 columns]

# %%
train, test = train_test_split(data, random_state = 10, train_size = 0.8, stratify = data["attrition_flag"])

# %%
train, test_init = train_test_split(train, random_state = 10, train_size = 0.8, stratify = train["attrition_flag"])

# %%
train.head()
# Out:
#       clientnum     attrition_flag  customer_age gender  dependent_count  \
# 2147  770882508  Existing Customer            38      M                2
# 7967  712200033  Existing Customer            44      F                4
# 9892  806917983  Existing Customer            32      F                2
# 7983  715463133  Existing Customer            40      M                5
# 5638  711824358  Existing Customer            44      F                4
#
#      education_level marital_status income_category card_category  \
# 2147         College        Married    $80K - $120K          Blue
# 7967     High School         Single  Less than $40K          Blue
# 9892        Graduate       Divorced         Unknown        Silver
# 7983     High School         Single         $120K +          Blue
# 5638         College         Single  Less than $40K          Blue
#
#       months_on_book  ...  months_inactive_12_mon  contacts_count_12_mon  \
# 2147              24  ...                       1                      5
# 7967              36  ...                       3                      3
# 9892              27  ...                       3                      1
# 7983              31  ...                       1                      3
# 5638              31  ...                       3                      2
#
#       credit_limit  total_revolving_bal  avg_open_to_buy  \
# 2147       17162.0                  773          16389.0
# 7967        3024.0                    0           3024.0
# 9892       33779.0                 1526          32253.0
# 7983       34516.0                 1427          33089.0
# 5638        3228.0                    0           3228.0
#
#       total_amt_chng_q4_q1  total_trans_amt  total_trans_ct  \
# 2147                 1.238             2457              54
# 7967                 0.750             4983              78
# 9892                 0.879            15200             126
# 7983                 0.706             3699              64
# 5638                 0.747             4524              70
#
#       total_ct_chng_q4_q1  avg_utilization_ratio
# 2147                1.000                  0.045
# 7967                0.733                  0.000
# 9892                0.800                  0.045
# 7983                0.488                  0.041
# 5638                0.667                  0.000
#
# [5 rows x 21 columns]

# %%
test.head()
# Out:
#       clientnum     attrition_flag  customer_age gender  dependent_count  \
# 3933  815240358  Existing Customer            47      F                3
# 2790  779284833  Existing Customer            55      M                2
# 8663  719658858  Existing Customer            50      F                4
# 731   719459358  Existing Customer            52      M                1
# 3335  734924658  Existing Customer            47      F                5
#
#      education_level marital_status income_category card_category  \
# 3933      Uneducated        Married         Unknown          Blue
# 2790   Post-Graduate         Single     $60K - $80K          Blue
# 8663       Doctorate        Married         Unknown        Silver
# 731        Doctorate        Married         $120K +          Blue
# 3335     High School        Married  Less than $40K          Blue
#
#       months_on_book  ...  months_inactive_12_mon  contacts_count_12_mon  \
# 3933              42  ...                       1                      4
# 2790              37  ...                       3                      1
# 8663              36  ...                       2                      1
# 731               41  ...                       2                      2
# 3335              36  ...                       3                      1
#
#       credit_limit  total_revolving_bal  avg_open_to_buy  \
# 3933       25027.0                 1501          23526.0
# 2790       22127.0                 1799          20328.0
# 8663       34516.0                 2096          32420.0
# 731        33864.0                  989          32875.0
# 3335        1478.0                  792            686.0
#
#       total_amt_chng_q4_q1  total_trans_amt  total_trans_ct  \
# 3933                 1.063             3357              62
# 2790                 0.758             3591              63
# 8663                 0.666             7042              73
# 731                  1.219             1751              48
# 3335                 0.873             4123              67
#
#       total_ct_chng_q4_q1  avg_utilization_ratio
# 3933                0.771                  0.060
# 2790                0.750                  0.081
# 8663                0.553                  0.061
# 731                 0.920                  0.029
# 3335                0.489                  0.536
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Hardcoded Feature Engineering

# %%
train["revolving_trans"] = train["total_revolving_bal"]/train["total_trans_amt"]
test_init["revolving_trans"] = test_init["total_revolving_bal"]/test_init["total_trans_amt"]
test["revolving_trans"] = test["total_revolving_bal"]/test["total_trans_amt"]

# %%
train["marriage_education"] = train["marital_status"] + "_" + train["education_level"]
test_init["marriage_education"] = test_init["marital_status"] + "_" + test_init["education_level"]
test["marriage_education"] = test["marital_status"] + "_" + test["education_level"]

# %%
train["attrition_flag"] = train["attrition_flag"].replace(["Attrited Customer","Existing Customer"], [1,0]).astype(int)
test["attrition_flag"] = test["attrition_flag"].replace(["Attrited Customer","Existing Customer"], [1,0]).astype(int)
test_init["attrition_flag"] = test_init["attrition_flag"].replace(["Attrited Customer","Existing Customer"], [1,0]).astype(int)

# %% [markdown]
# ### Data deduplication

# %%
train_0 = train[train["attrition_flag"] == 0]
train_0.head()
# Out:
#       clientnum  attrition_flag  customer_age gender  dependent_count  \
# 2147  770882508               0            38      M                2
# 7967  712200033               0            44      F                4
# 9892  806917983               0            32      F                2
# 7983  715463133               0            40      M                5
# 5638  711824358               0            44      F                4
#
#      education_level marital_status income_category card_category  \
# 2147         College        Married    $80K - $120K          Blue
# 7967     High School         Single  Less than $40K          Blue
# 9892        Graduate       Divorced         Unknown        Silver
# 7983     High School         Single         $120K +          Blue
# 5638         College         Single  Less than $40K          Blue
#
#       months_on_book  ...  credit_limit  total_revolving_bal  avg_open_to_buy  \
# 2147              24  ...       17162.0                  773          16389.0
# 7967              36  ...        3024.0                    0           3024.0
# 9892              27  ...       33779.0                 1526          32253.0
# 7983              31  ...       34516.0                 1427          33089.0
# 5638              31  ...        3228.0                    0           3228.0
#
#       total_amt_chng_q4_q1  total_trans_amt  total_trans_ct  \
# 2147                 1.238             2457              54
# 7967                 0.750             4983              78
# 9892                 0.879            15200             126
# 7983                 0.706             3699              64
# 5638                 0.747             4524              70
#
#       total_ct_chng_q4_q1  avg_utilization_ratio  revolving_trans  \
# 2147                1.000                  0.045         0.314611
# 7967                0.733                  0.000         0.000000
# 9892                0.800                  0.045         0.100395
# 7983                0.488                  0.041         0.385780
# 5638                0.667                  0.000         0.000000
#
#       marriage_education
# 2147     Married_College
# 7967  Single_High School
# 9892   Divorced_Graduate
# 7983  Single_High School
# 5638      Single_College
#
# [5 rows x 23 columns]

# %%
train_1 = train[train["attrition_flag"] == 1]
train_1.head()
# Out:
#       clientnum  attrition_flag  customer_age gender  dependent_count  \
# 5562  787665258               1            47      F                3
# 6731  711122958               1            41      F                3
# 2174  712551258               1            39      M                1
# 7973  820694133               1            60      F                0
# 2284  710586483               1            26      F                0
#
#      education_level marital_status income_category card_category  \
# 5562         Unknown        Married  Less than $40K          Blue
# 6731        Graduate         Single  Less than $40K          Blue
# 2174      Uneducated        Married  Less than $40K          Blue
# 7973     High School        Married         Unknown          Blue
# 2284     High School         Single         Unknown          Blue
#
#       months_on_book  ...  credit_limit  total_revolving_bal  avg_open_to_buy  \
# 5562              37  ...        1438.3                    0           1438.3
# 6731              33  ...        1764.0                    0           1764.0
# 2174              36  ...        4247.0                    0           4247.0
# 7973              55  ...        5549.0                    0           5549.0
# 2284              13  ...        6152.0                    0           6152.0
#
#       total_amt_chng_q4_q1  total_trans_amt  total_trans_ct  \
# 5562                 0.749             2393              36
# 6731                 0.552             2105              57
# 2174                 0.405              847              17
# 7973                 0.703             2412              38
# 2284                 0.391              968              23
#
#       total_ct_chng_q4_q1  avg_utilization_ratio  revolving_trans  \
# 5562                0.636                    0.0              0.0
# 6731                0.839                    0.0              0.0
# 2174                0.133                    0.0              0.0
# 7973                0.520                    0.0              0.0
# 2284                0.533                    0.0              0.0
#
#        marriage_education
# 5562      Married_Unknown
# 6731      Single_Graduate
# 2174   Married_Uneducated
# 7973  Married_High School
# 2284   Single_High School
#
# [5 rows x 23 columns]

# %%
train_0 = train_0.drop_duplicates()

# %% [markdown]
# ### Class balancing

# %%
rand_list = list(np.random.randint(0, len(train_0), len(train_1)))

# %%
train_0 = train_0.iloc[rand_list,]
train_0.shape
# Out:
# (1041, 23)

# %%
train_new = pd.concat([train_0, train_1], axis = 0)
train_new.head()
# Out:
#       clientnum  attrition_flag  customer_age gender  dependent_count  \
# 2885  788360283               0            33      M                1
# 4978  716013858               0            53      M                0
# 4679  821424483               0            51      F                1
# 3861  818308533               0            47      M                5
# 4279  780203883               0            43      F                3
#
#      education_level marital_status income_category card_category  \
# 2885        Graduate         Single    $80K - $120K          Blue
# 4978        Graduate         Single    $80K - $120K          Blue
# 4679     High School         Single  Less than $40K          Blue
# 3861   Post-Graduate        Married  Less than $40K          Blue
# 4279       Doctorate       Divorced         Unknown          Blue
#
#       months_on_book  ...  credit_limit  total_revolving_bal  avg_open_to_buy  \
# 2885              26  ...        1438.3                    0           1438.3
# 4978              34  ...       20231.0                 1434          18797.0
# 4679              47  ...        1438.3                    0           1438.3
# 3861              41  ...        3532.0                    0           3532.0
# 4279              33  ...        5738.0                    0           5738.0
#
#       total_amt_chng_q4_q1  total_trans_amt  total_trans_ct  \
# 2885                 0.865             2557              55
# 4978                 0.543             5002              78
# 4679                 0.826             4242              70
# 3861                 0.820             3162              56
# 4279                 0.852             4375              73
#
#       total_ct_chng_q4_q1  avg_utilization_ratio  revolving_trans  \
# 2885                0.618                  0.000         0.000000
# 4978                0.660                  0.071         0.286685
# 4679                0.458                  0.000         0.000000
# 3861                0.600                  0.000         0.000000
# 4279                0.622                  0.000         0.000000
#
#          marriage_education
# 2885        Single_Graduate
# 4978        Single_Graduate
# 4679     Single_High School
# 3861  Married_Post-Graduate
# 4279     Divorced_Doctorate
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Splitting into independent and dependent variables

# %%
x_train, y_train = train_new.drop(['attrition_flag','gender','clientnum'], axis = 1), train_new["attrition_flag"]

# %%
x_test, y_test = test.drop(['attrition_flag','gender','clientnum'], axis = 1), test["attrition_flag"]

# %%
x_test_init, y_test_init = test_init.drop(['attrition_flag','gender','clientnum'], axis = 1), test_init["attrition_flag"]

# %% [markdown]
# ### Gathering categorical and numerical columns

# %%
num = []
cat = []
columns = list(x_train.columns)
for col in columns:
    if is_numeric_dtype(x_train[col]):
        num.append(col)
    elif is_string_dtype(x_train[col]):
        cat.append(col)

# %%
num
# Out:
# ['customer_age',
#  'dependent_count',
#  'months_on_book',
#  'total_relationship_count',
#  'months_inactive_12_mon',
#  'contacts_count_12_mon',
#  'credit_limit',
#  'total_revolving_bal',
#  'avg_open_to_buy',
#  'total_amt_chng_q4_q1',
#  'total_trans_amt',
#  'total_trans_ct',
#  'total_ct_chng_q4_q1',
#  'avg_utilization_ratio',
#  'revolving_trans']

# %% [markdown]
# ### Preprocessing tools

# %%
one_hot = OneHotEncoder()
min_max = MinMaxScaler()
sd = StandardScaler()
le = LabelEncoder()

# %%
ct = ColumnTransformer([("one_hot", one_hot, cat), ("min_max", min_max, num)])

# %% [markdown]
# ### Pipeline Creation

# %%
pipeline = Pipeline([("ct", ct), ("xgb", XGBClassifier())])

# %% [markdown]
# ### Random Search

# %%
parameters = {
    "xgb__n_estimators": [20,40,60,80,100],
    "xgb__subsample":[0.6, 0.8, 1],
    "xgb__learning_rate":[0.01, 0.1, 0.5, 1],
    "xgb__gamma":[0.01, 0.1, 1, 5],
    "xgb__colsample_bytree":[0.5, 0.7, 0.9, 1],
    "xgb__reg_alpha":[0, 0.1, 0.5]
}

# %%
random_search = RandomizedSearchCV(pipeline, parameters, cv = 5, n_iter = 30)

# %%
random_search.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('ct',
#                                               ColumnTransformer(transformers=[('one_hot',
#                                                                                OneHotEncoder(),
#                                                                                ['education_level',
#                                                                                 'marital_status',
#                                                                                 'income_category',
#                                                                                 'card_category',
#                                                                                 'marriage_education']),
#                                                                               ('min_max',
#                                                                                MinMaxScaler(),
#                                                                                ['customer_age',
#                                                                                 'dependent_count',
#                                                                                 'months_on_book',
#                                                                                 'total_relationship_count',
#                                                                                 'months_inactive_12_mon',
#                                                                                 'contacts_cou...
#                                                             monotone_constraints=None,
#                                                             n_estimators=100,
#                                                             n_jobs=None,
#                                                             num_parallel_tree=None,
#                                                             predictor=None,
#                                                             random_state=None, ...))]),
#                    n_iter=30,
#                    param_distributions={'xgb__colsample_bytree': [0.5, 0.7, 0.9,
#                                                                   1],
#                                         'xgb__gamma': [0.01, 0.1, 1, 5],
#                                         'xgb__learning_rate': [0.01, 0.1, 0.5,
#                                                                1],
#                                         'xgb__n_estimators': [20, 40, 60, 80,
#                                                               100],
#                                         'xgb__reg_alpha': [0, 0.1, 0.5],
#                                         'xgb__subsample': [0.6, 0.8, 1]})

# %%
random_search.best_params_
# Out:
# {'xgb__subsample': 0.8,
#  'xgb__reg_alpha': 0.5,
#  'xgb__n_estimators': 100,
#  'xgb__learning_rate': 0.1,
#  'xgb__gamma': 0.1,
#  'xgb__colsample_bytree': 0.5}

# %%
random_search.best_score_
# Out:
# 0.9577326600258255

# %%
model = random_search.best_estimator_

# %% [markdown]
# ### Cross Validation via pipeline

# %%
cross_val_score(model, x_train, y_train, cv = 5, scoring = "precision")
# Out:
# array([0.93867925, 0.95794393, 0.93925234, 0.96135266, 0.95714286])

# %% [markdown]
# ### Fitting pipeline on training data

# %%
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('ct',
#                  ColumnTransformer(transformers=[('one_hot', OneHotEncoder(),
#                                                   ['education_level',
#                                                    'marital_status',
#                                                    'income_category',
#                                                    'card_category',
#                                                    'marriage_education']),
#                                                  ('min_max', MinMaxScaler(),
#                                                   ['customer_age',
#                                                    'dependent_count',
#                                                    'months_on_book',
#                                                    'total_relationship_count',
#                                                    'months_inactive_12_mon',
#                                                    'contacts_count_12_mon',
#                                                    'credit_limit',
#                                                    'total_r...
#                                feature_types=None, gamma=0.1, gpu_id=None,
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=0.1,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, n_estimators=100,
#                                n_jobs=None, num_parallel_tree=None,
#                                predictor=None, random_state=None, ...))])

# %% [markdown]
# ### Evaluating pipeline's accuracy

# %% [markdown]
# #### Training data results

# %%
pred_train = model.predict(x_train)
print(classification_report(y_train, pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1041
#            1       1.00      1.00      1.00      1041
#
#     accuracy                           1.00      2082
#    macro avg       1.00      1.00      1.00      2082
# weighted avg       1.00      1.00      1.00      2082

# %%
conf = confusion_matrix(y_train, pred_train)
sns.heatmap(conf, annot = True, cmap = "RdBu")
# Out:
# <AxesSubplot:>

# %%
train_new["prediction"] = pred_train
train_probs = model.predict_proba(x_train)
train_new["prob_0"], train_new["prob_1"] = train_probs[:,0], train_probs[:,1]
train_new.head()
# Out:
#       clientnum  attrition_flag  customer_age gender  dependent_count  \
# 2885  788360283               0            33      M                1
# 4978  716013858               0            53      M                0
# 4679  821424483               0            51      F                1
# 3861  818308533               0            47      M                5
# 4279  780203883               0            43      F                3
#
#      education_level marital_status income_category card_category  \
# 2885        Graduate         Single    $80K - $120K          Blue
# 4978        Graduate         Single    $80K - $120K          Blue
# 4679     High School         Single  Less than $40K          Blue
# 3861   Post-Graduate        Married  Less than $40K          Blue
# 4279       Doctorate       Divorced         Unknown          Blue
#
#       months_on_book  ...  total_amt_chng_q4_q1  total_trans_amt  \
# 2885              26  ...                 0.865             2557
# 4978              34  ...                 0.543             5002
# 4679              47  ...                 0.826             4242
# 3861              41  ...                 0.820             3162
# 4279              33  ...                 0.852             4375
#
#       total_trans_ct  total_ct_chng_q4_q1  avg_utilization_ratio  \
# 2885              55                0.618                  0.000
# 4978              78                0.660                  0.071
# 4679              70                0.458                  0.000
# 3861              56                0.600                  0.000
# 4279              73                0.622                  0.000
#
#       revolving_trans     marriage_education  prediction    prob_0    prob_1
# 2885         0.000000        Single_Graduate           0  0.857085  0.142915
# 4978         0.286685        Single_Graduate           0  0.997917  0.002083
# 4679         0.000000     Single_High School           0  0.984900  0.015100
# 3861         0.000000  Married_Post-Graduate           0  0.856853  0.143147
# 4279         0.000000     Divorced_Doctorate           0  0.978749  0.021251
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Initial test data results

# %%
pred_test_init = model.predict(x_test_init)
print(classification_report(y_test_init, pred_test_init))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97      1360
#            1       0.78      0.95      0.86       261
#
#     accuracy                           0.95      1621
#    macro avg       0.89      0.95      0.91      1621
# weighted avg       0.96      0.95      0.95      1621

# %%
conf = confusion_matrix(y_test_init, pred_test_init)
sns.heatmap(conf, annot = True, cmap = "RdBu")
# Out:
# <AxesSubplot:>

# %%
test_init["prediction"] = pred_test_init
test_init_probs = model.predict_proba(x_test_init)
test_init["prob_0"], test_init["prob_1"] = test_init_probs[:,0], test_init_probs[:,1]
test_init.head()
# Out:
#       clientnum  attrition_flag  customer_age gender  dependent_count  \
# 2447  712040433               0            54      F                1
# 2052  765824058               0            46      M                4
# 7923  718548558               0            53      F                3
# 2293  710567508               0            53      M                3
# 4750  715776033               0            46      M                5
#
#      education_level marital_status income_category card_category  \
# 2447     High School        Married  Less than $40K          Blue
# 2052       Doctorate        Married    $80K - $120K          Blue
# 7923         Unknown         Single  Less than $40K          Blue
# 2293     High School        Married    $80K - $120K          Blue
# 4750      Uneducated         Single     $60K - $80K          Blue
#
#       months_on_book  ...  total_amt_chng_q4_q1  total_trans_amt  \
# 2447              43  ...                 0.697             2097
# 2052              39  ...                 0.907             3784
# 7923              42  ...                 0.927             4272
# 2293              44  ...                 0.571             1387
# 4750              33  ...                 0.572             4116
#
#       total_trans_ct  total_ct_chng_q4_q1  avg_utilization_ratio  \
# 2447              57                0.541                  0.954
# 2052              74                0.609                  0.301
# 7923              70                0.750                  0.700
# 2293              33                0.650                  0.094
# 4750              68                0.700                  0.000
#
#       revolving_trans   marriage_education  prediction    prob_0    prob_1
# 2447         1.049118  Married_High School           1  0.443673  0.556327
# 2052         0.406712    Married_Doctorate           0  0.991505  0.008495
# 7923         0.477762       Single_Unknown           0  0.996783  0.003217
# 2293         1.587599  Married_High School           0  0.989269  0.010731
# 4750         0.000000    Single_Uneducated           0  0.994645  0.005355
#
# [5 rows x 26 columns]

# %%
pred_init_score = test_init["prob_1"]

# %% [markdown]
# #### Precision - Recall Curve

# %%
precisions, recalls, thresholds = precision_recall_curve(y_test_init, pred_init_score)

# %%
plt.figure(figsize = (15,8))
sns.lineplot(x = thresholds, y = precisions[:-1], markers = "b--", label="Precision", linewidth=2)
sns.lineplot(x = thresholds, y = recalls[:-1], markers = "g-", label="Recall", linewidth=2)
plt.axvline(x = [0.5], color = "black", linestyle = "dashed")
plt.title("Evolution of Precision and Recall as a function of threshold")
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.lineplot(x = recalls[:-1], y = precisions[:-1], markers = "b--", label="Precision", linewidth=2)
plt.title("Precision vs Recall Curve")
#plt.vlines(threshold, 0, 1.0, "k", "dotted", label="threshold")
[...]  # beautify the figure: add grid, legend, axis, labels, and circles
plt.show();

# %% [markdown]
# #### ROC Curve/ROC AUC Score

# %%
roc_auc_score(y_test_init, pred_init_score)
# Out:
# 0.9882691007437457

# %%
fpr, tpr, thresholds = roc_curve(y_test_init, pred_init_score)

# %%
plt.figure(figsize = (15,8))
sns.lineplot(x = fpr, y = tpr, linewidth=2, label="ROC curve", color = "red")
plt.plot([0, 1], [0, 1], 'k:')
plt.title("ROC Curve")
plt.show()

# %% [markdown]
# #### Feature Importance

# %%
vip = model.steps[1][1].feature_importances_
vip
# Out:
# array([0.0108621 , 0.0181492 , 0.00531914, 0.01363574, 0.00548477,
#        0.01107028, 0.00384878, 0.01231897, 0.01472252, 0.00828901,
#        0.01266738, 0.00957458, 0.00779829, 0.01326938, 0.00291244,
#        0.00889535, 0.01020722, 0.01839698, 0.05543191, 0.        ,
#        0.00828161, 0.        , 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.00780587, 0.        ,
#        0.00723752, 0.01509919, 0.0063218 , 0.00137792, 0.01125131,
#        0.0067773 , 0.        , 0.00447673, 0.00707275, 0.0045191 ,
#        0.00524694, 0.00759846, 0.        , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 0.        , 0.03097083,
#        0.01057674, 0.01100144, 0.06103385, 0.04243639, 0.03394309,
#        0.01938797, 0.11506602, 0.02541513, 0.03457488, 0.06831292,
#        0.10067345, 0.04677847, 0.02214207, 0.04176626], dtype=float32)

# %%
model.steps[0][1].transformers_[0][1].get_feature_names()
# Out:
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# array(['x0_College', 'x0_Doctorate', 'x0_Graduate', 'x0_High School',
#        'x0_Post-Graduate', 'x0_Uneducated', 'x0_Unknown', 'x1_Divorced',
#        'x1_Married', 'x1_Single', 'x1_Unknown', 'x2_$120K +',
#        'x2_$40K - $60K', 'x2_$60K - $80K', 'x2_$80K - $120K',
#        'x2_Less than $40K', 'x2_Unknown', 'x3_Blue', 'x3_Gold',
#        'x3_Platinum', 'x3_Silver', 'x4_Divorced_College',
#        'x4_Divorced_Doctorate', 'x4_Divorced_Graduate',
#        'x4_Divorced_High School', 'x4_Divorced_Post-Graduate',
#        'x4_Divorced_Uneducated', 'x4_Divorced_Unknown',
#        'x4_Married_College', 'x4_Married_Doctorate',
#        'x4_Married_Graduate', 'x4_Married_High School',
#        'x4_Married_Post-Graduate', 'x4_Married_Uneducated',
#        'x4_Married_Unknown', 'x4_Single_College', 'x4_Single_Doctorate',
#        'x4_Single_Graduate', 'x4_Single_High School',
#        'x4_Single_Post-Graduate', 'x4_Single_Uneducated',
#        'x4_Single_Unknown', 'x4_Unknown_College', 'x4_Unknown_Doctorate',
#        'x4_Unknown_Graduate', 'x4_Unknown_High School',
#        'x4_Unknown_Post-Graduate', 'x4_Unknown_Uneducated',
#        'x4_Unknown_Unknown'], dtype=object)

# %%
#create df with vip info
feature_importances_info = pd.DataFrame({'feat_names':list(model.steps[0][1].transformers_[0][1].get_feature_names()) + num, 'vip': vip})

#get sign and magnitude information
feature_importances_info = feature_importances_info.assign(feature_importances_mag = abs(feature_importances_info['vip']),
                             feature_importances_sign = np.sign(feature_importances_info['vip']))
feature_importances_info = feature_importances_info.set_index('feat_names').sort_values(by='feature_importances_mag', ascending=False)
feature_importances_info.head(10)
# Out:
#                                vip  feature_importances_mag  \
# feat_names
# total_revolving_bal       0.115066                 0.115066
# total_trans_ct            0.100673                 0.100673
# total_trans_amt           0.068313                 0.068313
# total_relationship_count  0.061034                 0.061034
# x3_Gold                   0.055432                 0.055432
# total_ct_chng_q4_q1       0.046778                 0.046778
# months_inactive_12_mon    0.042436                 0.042436
# revolving_trans           0.041766                 0.041766
# total_amt_chng_q4_q1      0.034575                 0.034575
# contacts_count_12_mon     0.033943                 0.033943
#
#                           feature_importances_sign
# feat_names
# total_revolving_bal                            1.0
# total_trans_ct                                 1.0
# total_trans_amt                                1.0
# total_relationship_count                       1.0
# x3_Gold                                        1.0
# total_ct_chng_q4_q1                            1.0
# months_inactive_12_mon                         1.0
# revolving_trans                                1.0
# total_amt_chng_q4_q1                           1.0
# contacts_count_12_mon                          1.0

# %%
sns.barplot(y=feature_importances_info.index[:10], x='feature_importances_mag', hue='feature_importances_sign', 
            data=feature_importances_info[:10], orient='h', dodge=False);
# Out:
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/seaborn/categorical.py:381: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) < "3.0":
# /accre/arch/easybuild/software/BinDist/Anaconda3/2022.05/lib/python3.9/site-packages/setuptools/_distutils/version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %%
len(feature_importances_info[feature_importances_info["vip"] > 0])
# Out:
# 47

# %% [markdown]
# #### Holdout test data results

# %%
pred_test = model.predict(x_test)
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96      1701
#            1       0.73      0.97      0.83       325
#
#     accuracy                           0.94      2026
#    macro avg       0.86      0.95      0.90      2026
# weighted avg       0.95      0.94      0.94      2026

# %%
conf = confusion_matrix(y_test, pred_test)
sns.heatmap(conf, annot = True, cmap = "RdBu")
# Out:
# <AxesSubplot:>

# %%
test["prediction"] = pred_test
test_probs = model.predict_proba(x_test)
test["prob_0"], test["prob_1"] = test_probs[:,0], test_probs[:,1]
test.head()
# Out:
#       clientnum  attrition_flag  customer_age gender  dependent_count  \
# 3933  815240358               0            47      F                3
# 2790  779284833               0            55      M                2
# 8663  719658858               0            50      F                4
# 731   719459358               0            52      M                1
# 3335  734924658               0            47      F                5
#
#      education_level marital_status income_category card_category  \
# 3933      Uneducated        Married         Unknown          Blue
# 2790   Post-Graduate         Single     $60K - $80K          Blue
# 8663       Doctorate        Married         Unknown        Silver
# 731        Doctorate        Married         $120K +          Blue
# 3335     High School        Married  Less than $40K          Blue
#
#       months_on_book  ...  total_amt_chng_q4_q1  total_trans_amt  \
# 3933              42  ...                 1.063             3357
# 2790              37  ...                 0.758             3591
# 8663              36  ...                 0.666             7042
# 731               41  ...                 1.219             1751
# 3335              36  ...                 0.873             4123
#
#       total_trans_ct  total_ct_chng_q4_q1  avg_utilization_ratio  \
# 3933              62                0.771                  0.060
# 2790              63                0.750                  0.081
# 8663              73                0.553                  0.061
# 731               48                0.920                  0.029
# 3335              67                0.489                  0.536
#
#       revolving_trans    marriage_education  prediction    prob_0    prob_1
# 3933         0.447125    Married_Uneducated           0  0.998163  0.001837
# 2790         0.500975  Single_Post-Graduate           0  0.994280  0.005720
# 8663         0.297643     Married_Doctorate           0  0.887760  0.112240
# 731          0.564820     Married_Doctorate           0  0.994976  0.005024
# 3335         0.192093   Married_High School           0  0.989031  0.010969
#
# [5 rows x 26 columns]

# %%
pred_score = test["prob_1"]

# %% [markdown]
# #### Precision - Recall Curve

# %%
precisions, recalls, thresholds = precision_recall_curve(y_test, pred_score)

# %%
plt.figure(figsize = (15,8))
sns.lineplot(x = thresholds, y = precisions[:-1], markers = "b--", label="Precision", linewidth=2)
sns.lineplot(x = thresholds, y = recalls[:-1], markers = "g-", label="Recall", linewidth=2)
plt.axvline(x = [0.5], color = "black", linestyle = "dashed")
plt.title("Evolution of Precision and Recall as a function of threshold")
plt.show()

# %%
plt.figure(figsize = (15,8))
sns.lineplot(x = recalls[:-1], y = precisions[:-1], markers = "b--", label="Precision", linewidth=2)
plt.title("Precision vs Recall Curve")
#plt.vlines(threshold, 0, 1.0, "k", "dotted", label="threshold")
[...]  # beautify the figure: add grid, legend, axis, labels, and circles
plt.show();

# %% [markdown]
# #### ROC Curve/ROC AUC Score

# %%
roc_auc_score(y_test, pred_score)
# Out:
# 0.9873305295527518

# %%
fpr, tpr, thresholds = roc_curve(y_test, pred_score)

# %%
plt.figure(figsize = (15,8))
sns.lineplot(x = fpr, y = tpr, linewidth=2, label="ROC curve", color = "red")
plt.plot([0, 1], [0, 1], 'k:')
plt.title("ROC Curve")
plt.show()
